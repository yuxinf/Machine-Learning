# %%
# %matplotlib inline
import numpy
import matplotlib.pyplot as plt
import scipy.io
data = scipy.io.loadmat('MSdata.mat')
import random

# %%
data["trainx"][0]
# Out:
# array([  4.99435700e+01,   2.14711400e+01,   7.30775000e+01,
#          8.74861000e+00,  -1.74062800e+01,  -1.30990500e+01,
#         -2.50120200e+01,  -1.22325700e+01,   7.83089000e+00,
#         -2.46783000e+00,   3.32136000e+00,  -2.31521000e+00,
#          1.02055600e+01,   6.11109130e+02,   9.51089600e+02,
#          6.98114280e+02,   4.08984850e+02,   3.83709120e+02,
#          3.26515120e+02,   2.38113270e+02,   2.51424140e+02,
#          1.87173510e+02,   1.00426520e+02,   1.79194980e+02,
#         -8.41558000e+00,  -3.17870380e+02,   9.58626600e+01,
#          4.81025900e+01,  -9.56630300e+01,  -1.80621500e+01,
#          1.96984000e+00,   3.44243800e+01,   1.17267000e+01,
#          1.36790000e+00,   7.79444000e+00,  -3.69940000e-01,
#         -1.33678520e+02,  -8.32616500e+01,  -3.72976500e+01,
#          7.30466700e+01,  -3.73668400e+01,  -3.13853000e+00,
#         -2.42153100e+01,  -1.32306600e+01,   1.59380900e+01,
# ...

# %%
data["trainy"][0]
# Out:
# array([2001], dtype=uint16)

# %%
data["testx"][0]
# Out:
# array([  4.54420000e+01,  -3.07497600e+01,   3.17858700e+01,
#          4.63569000e+00,  -1.51489400e+01,   2.33700000e-01,
#         -1.19796800e+01,  -9.59708000e+00,   6.48111000e+00,
#         -8.89073000e+00,   4.02405000e+00,  -2.28873000e+00,
#          1.79020400e+01,   1.37712225e+03,   1.76204257e+03,
#          9.47344300e+02,   5.62281400e+02,   5.24268110e+02,
#          3.61254100e+02,   5.14535070e+02,   2.47701260e+02,
#          3.99788800e+02,   2.05365210e+02,   2.11868700e+02,
#          4.48897100e+01,  -2.99639230e+02,  -2.27641690e+02,
#          7.34210000e+00,  -8.58005700e+01,   1.68121100e+01,
#         -4.11858100e+01,  -1.20085800e+01,  -4.19211700e+01,
#         -2.65231200e+01,  -1.21976500e+01,   8.96110400e+01,
#         -2.66078340e+02,  -2.30312230e+02,  -1.68296090e+02,
#          3.84037100e+01,   3.18401600e+01,   2.89807100e+01,
#         -9.87344700e+01,   2.64656500e+01,  -3.02327200e+01,
# ...

# %%
#split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data["trainx"],data["trainy"], test_size =0.2, random_state = 30 )

# %%
#fitting multiple linear regression to the training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
def test_linear(y_pred, y_test):
    n = len(y_pred)
    total = 0
    for i in range(n):
        total += abs(y_pred[i][0]-y_test[i][0])
    mae = total/n
    return mae    

well = test_linear(y_pred, y_test)
print(well)
# Out:
# 6.79024944222

# %%
#building the optimal model using backward elimination
featurelist = []
for i in range(91):
    featurelist.append(i)
import statsmodels.formula.api as sm
data["trainx"] = numpy.append(arr = numpy.ones((463715,1)).astype(int), values = data["trainx"], axis =1)
X_opt = data["trainx"][:, featurelist]
regressor_OLS = sm.OLS(endog = data["trainy"], exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     1604.
# Date:                Thu, 22 Mar 2018   Prob (F-statistic):               0.00
# Time:                        20:57:29   Log-Likelihood:            -1.7045e+06
# No. Observations:              463715   AIC:                         3.409e+06
# Df Residuals:                  463624   BIC:                         3.410e+06
# Df Model:                          90
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1951.1222      0.199   9787.748      0.000    1950.731    1951.513
# ...

# %%
featurelist.remove(79)
X_opt = data["trainx"][:, featurelist]
regressor_OLS = sm.OLS(endog = data["trainy"], exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     1622.
# Date:                Thu, 22 Mar 2018   Prob (F-statistic):               0.00
# Time:                        20:58:54   Log-Likelihood:            -1.7045e+06
# No. Observations:              463715   AIC:                         3.409e+06
# Df Residuals:                  463625   BIC:                         3.410e+06
# Df Model:                          89
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1951.1220      0.199   9792.293      0.000    1950.731    1951.513
# ...

# %%
featurelist.remove(51)
X_opt = data["trainx"][:, featurelist]
regressor_OLS = sm.OLS(endog = data["trainy"], exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     1641.
# Date:                Thu, 22 Mar 2018   Prob (F-statistic):               0.00
# Time:                        20:59:37   Log-Likelihood:            -1.7045e+06
# No. Observations:              463715   AIC:                         3.409e+06
# Df Residuals:                  463626   BIC:                         3.410e+06
# Df Model:                          88
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1951.1223      0.199   9797.509      0.000    1950.732    1951.513
# ...

# %%
featurelist.remove(53)
X_opt = data["trainx"][:, featurelist]
regressor_OLS = sm.OLS(endog = data["trainy"], exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     1659.
# Date:                Thu, 22 Mar 2018   Prob (F-statistic):               0.00
# Time:                        21:00:28   Log-Likelihood:            -1.7045e+06
# No. Observations:              463715   AIC:                         3.409e+06
# Df Residuals:                  463627   BIC:                         3.410e+06
# Df Model:                          87
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1951.0976      0.199   9798.310      0.000    1950.707    1951.488
# ...

# %%
featurelist.remove(52)
X_opt = data["trainx"][:, featurelist]
regressor_OLS = sm.OLS(endog = data["trainy"], exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     1678.
# Date:                Thu, 22 Mar 2018   Prob (F-statistic):               0.00
# Time:                        21:01:02   Log-Likelihood:            -1.7046e+06
# No. Observations:              463715   AIC:                         3.409e+06
# Df Residuals:                  463628   BIC:                         3.410e+06
# Df Model:                          86
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1951.0913      0.199   9797.921      0.000    1950.701    1951.482
# ...

# %%
featurelist.remove(82)
X_opt = data["trainx"][:, featurelist]
regressor_OLS = sm.OLS(endog = data["trainy"], exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     1697.
# Date:                Thu, 22 Mar 2018   Prob (F-statistic):               0.00
# Time:                        21:01:35   Log-Likelihood:            -1.7046e+06
# No. Observations:              463715   AIC:                         3.409e+06
# Df Residuals:                  463629   BIC:                         3.410e+06
# Df Model:                          85
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1951.1223      0.199   9801.406      0.000    1950.732    1951.512
# ...

# %%
#split data
from sklearn.model_selection import train_test_split
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_opt,data["trainy"], test_size =0.2, random_state = 30 )

#fitting multiple linear regression to the training set
from sklearn.linear_model import LinearRegression
regressor2 = LinearRegression()
regressor2.fit(X_train2, y_train2)

y_pred2 = regressor2.predict(X_test2)

# %%
def test_linear2(y_pred2, y_test2):
    n = len(y_pred2)
    total = 0
    for i in range(n):
        total += abs(y_pred2[i][0]-y_test2[i][0])
    mae = total/n
    return mae    

well2 = test_linear2(y_pred2, y_test2)
print(well2)
# Out:
# 6.79214632428
